# %%
import math

# %% [markdown]
# loaded CSV at the end of notebook

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as mt

# %%
mt.sqrt(25)
# Out:
# 5.0

# %%
from numpy import random

# %%
import numpy as np

# %%
# uniform random numbers in [0,1]
dataOne = random.rand(5,5)
dataOne
# Out:
# array([[0.59086946, 0.18032234, 0.50792755, 0.59040027, 0.7659384 ],
#        [0.08751058, 0.49542449, 0.62747274, 0.95628037, 0.24475117],
#        [0.46631961, 0.9083706 , 0.57586177, 0.77857377, 0.04625746],
#        [0.19215072, 0.05842358, 0.40735913, 0.12854083, 0.50893781],
#        [0.17688986, 0.66881284, 0.27052283, 0.25654016, 0.61865842]])

# %%
np.mean(dataOne)
# Out:
# 0.4924729496010678

# %%
print('I Love data Science')
# Out:
# I Love data Science

# %%
variableName = 25
variableName1 = 'I Love data Science'
print(variableName1)
type(variableName)
# Out:
# I Love data Science
# int

# %%
variableName = 25.0
type(variableName)
# Out:
# float

# %%
varOne = 25
varTwo = 25.0
varThree = varOne + varTwo
print(varThree)
# Out:
# 50.0

# %%
listName = [ ]
listOne = [1,2,3,4]
print(listOne[1:3])
# Out:
# [2, 3]

# %%
tel = {'jack': 4098, 'sape': 4139}
tel['jack']
# Out:
# 4098

# %%
intdi = {'int1': 1, 'int2': 2, 'int3': 4, 'int4': 9, 'int5': 16}

# %%
var1 = mt.sqrt(intdi['int4'])

# %%
var2 = mt.factorial(intdi['int3'])

# %%
var3 = mt.gcd(intdi['int2'],intdi['int5'])

# %% [markdown]
# print(intdi)
# print(var1)
# print(var2)
# print(var3)

# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/Administrator/Documents/class-job files/UT Data Analytics Class/C5 Data Science with Python/Task 1/CompleteResponses.csv")
print(df1[0:10])
# Out:
#          salary  age  elevel  car  zipcode        credit  brand
# 0  119806.54480   45       0   14        4  442037.71130      0
# 1  106880.47840   63       1   11        6   45007.17883      1
# 2   78020.75094   23       0   15        2   48795.32279      0
# 3   63689.93635   51       3    6        5   40888.87736      1
# 4   50873.61880   20       3   14        4  352951.49770      0
# 5  130812.74280   56       3   14        3  135943.02200      1
# 6  136459.33920   24       4    8        5   80500.56351      1
# 7  103866.89960   62       3    3        0  359803.89350      1
# 8   72298.80402   29       4   17        0  276298.69520      0
# 9   37803.33285   41       1    5        4  493219.26860      1

# %% [markdown]
# pulled in an old csv using pandas.  Did not run into any trouble or errors while trying this, had found another library when intially looking for steps on this piece called csv, but I found the information on pandas as well so I did not try with the csv library
#
# Installing python and the libraries was straightforward.  I had already had it done from a previous course (both python and the libraries due to installing anaconda).
#
# The tutorial for installing and running over some of the basics was useful.  It walks you over the basics but doesn't get too complicated while still giving you the information need to take on more complciated pieces.
#
# Again I think the main lesson behind all this was some of the basics.  I think getting people comfortable with different libraries is key since they are such a huge tool and getting people into using jupyter notebook is great.  I had worked a little bit with python in the past so a lot of the basics were not new to me, but I have not really gotten to use jupyter notebooks much at all (had mostly worked with random IDE) so I am excited to be able to give it a try during this.

# %%
df1
# Out:
#             salary  age  elevel  car  zipcode        credit  brand
# 0     119806.54480   45       0   14        4  442037.71130      0
# 1     106880.47840   63       1   11        6   45007.17883      1
# 2      78020.75094   23       0   15        2   48795.32279      0
# 3      63689.93635   51       3    6        5   40888.87736      1
# 4      50873.61880   20       3   14        4  352951.49770      0
# 5     130812.74280   56       3   14        3  135943.02200      1
# 6     136459.33920   24       4    8        5   80500.56351      1
# 7     103866.89960   62       3    3        0  359803.89350      1
# 8      72298.80402   29       4   17        0  276298.69520      0
# 9      37803.33285   41       1    5        4  493219.26860      1
# 10     63704.26156   48       4   16        5  299460.22740      1
# 11    128999.93560   52       1    6        0  152232.50980      0
# 12     57991.29599   52       3   20        4  227743.74970      1
# ...
